# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, StratifiedKFold
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.stats import uniform

# %%
from google.colab import drive
drive.mount('/content/Drive')
# Out:
# Mounted at /content/Drive

# %%
train_df = pd.read_csv('/content/Drive/My Drive/CS221_Datasets/after_clean_train.csv')
test_df = pd.read_csv('/content/Drive/My Drive/CS221_Datasets/after_clean_test.csv')

# %%
train_df.dropna(subset=['no_stopwords'], inplace=True)
test_df.dropna(subset=['no_stopwords'], inplace=True)

# %%
le = LabelEncoder()
train_df['labels'] = le.fit_transform(train_df['labels'])
test_df['labels'] = le.transform(test_df['labels'])

# %% [markdown]
# # Chia dữ liệu huấn luyện thành hai tập train và validation để tìm tham số tối ưu

# %%
X_train, X_val, y_train, y_val = train_test_split(train_df['no_stopwords'], train_df['labels'], test_size=0.2, stratify=train_df['labels'], random_state=42)

# %%
pipe = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('clf', MultinomialNB())
])

# %%
param_dist_nb = {
    'tfidf__max_features': [3000, 5000, 10000],
    'tfidf__ngram_range': [(1,1), (1,2), (1,3)],
    'tfidf__min_df': [1, 2, 3],
    'tfidf__sublinear_tf': [True, False],
    'tfidf__use_idf': [True, False],
    'tfidf__norm': [None]
}

# %%
random_search = RandomizedSearchCV(pipe, param_distributions=param_dist_nb, n_iter=20, scoring='f1_weighted', cv=3, verbose=2, n_jobs=-1)
random_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# RandomizedSearchCV(cv=3,
#                    estimator=Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                                              ('clf', MultinomialNB())]),
#                    n_iter=20, n_jobs=-1,
#                    param_distributions={'tfidf__max_features': [3000, 5000,
#                                                                 10000],
#                                         'tfidf__min_df': [1, 2, 3],
#                                         'tfidf__ngram_range': [(1, 1), (1, 2),
#                                                                (1, 3)],
#                                         'tfidf__norm': [None],
#                                         'tfidf__sublinear_tf': [True, False],
#                                         'tfidf__use_idf': [True, False]},
#                    scoring='f1_weighted', verbose=2)

# %%
best_params = random_search.best_params_
best_params
# Out:
# {'tfidf__use_idf': False,
#  'tfidf__sublinear_tf': False,
#  'tfidf__norm': None,
#  'tfidf__ngram_range': (1, 3),
#  'tfidf__min_df': 3,
#  'tfidf__max_features': 10000}

# %%
grid_param = {
    'tfidf__max_features': [10000, 11000, 12000],
    'tfidf__ngram_range': [(1, 2),(1, 3)],
    'tfidf__min_df': [3, 4, 5],
    'tfidf__sublinear_tf': [False],
    'tfidf__use_idf': [False],
    'tfidf__norm': [None]
}
grid_search = GridSearchCV(pipe, param_grid=grid_param, scoring='f1_weighted', cv=3, verbose=2, n_jobs=-1)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                                        ('clf', MultinomialNB())]),
#              n_jobs=-1,
#              param_grid={'tfidf__max_features': [10000, 11000, 12000],
#                          'tfidf__min_df': [3, 4, 5],
#                          'tfidf__ngram_range': [(1, 2), (1, 3)],
#                          'tfidf__norm': [None], 'tfidf__sublinear_tf': [False],
#                          'tfidf__use_idf': [False]},
#              scoring='f1_weighted', verbose=2)

# %%
grid_search.best_params_
# Out:
# {'tfidf__max_features': 12000,
#  'tfidf__min_df': 4,
#  'tfidf__ngram_range': (1, 3),
#  'tfidf__norm': None,
#  'tfidf__sublinear_tf': False,
#  'tfidf__use_idf': False}

# %%
grid_search.best_score_
# Out:
# np.float64(0.6994322162229413)

# %% [markdown]
# # Dự đoán trên tập Validation

# %%
y_pred_val = grid_search.predict(X_val)
print(classification_report(y_val, y_pred_val))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.74      0.76      6964
#            1       0.41      0.43      0.42      3488
#            2       0.79      0.80      0.80      6540
#
#     accuracy                           0.70     16992
#    macro avg       0.66      0.66      0.66     16992
# weighted avg       0.71      0.70      0.70     16992

# %% [markdown]
# # Train trên toàn bộ dữ liệu huấn luyện với tham số được lấy từ GridSearch ở trên

# %%
train_df = pd.read_csv('/content/Drive/My Drive/CS221_Datasets/after_clean_train.csv')
test_df = pd.read_csv('/content/Drive/My Drive/CS221_Datasets/after_clean_test.csv')

# %%
train_df.dropna(subset=['no_stopwords'], inplace=True)
test_df.dropna(subset=['no_stopwords'], inplace=True)

# %%
le = LabelEncoder()
train_df['labels'] = le.fit_transform(train_df['labels'])
test_df['labels'] = le.transform(test_df['labels'])

# %%
X_train, X_test, y_train, y_test = train_df['no_stopwords'], test_df['no_stopwords'], train_df['labels'], test_df['labels']

# %%
tfidf = TfidfVectorizer(max_features=12000, min_df=4, ngram_range=(1, 3), norm=None, sublinear_tf=False, use_idf=False)
mnb = MultinomialNB()

# %%
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %%
mnb.fit(X_train_tfidf, y_train)
# Out:
# MultinomialNB()

# %% [markdown]
# # Dự đoán trên dữ liệu kiểm thử

# %%
y_pred = mnb.predict(X_test_tfidf)

# %%
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.7055858450776669
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76      3960
#            1       0.40      0.42      0.41      1930
#            2       0.81      0.80      0.81      3831
#
#     accuracy                           0.71      9721
#    macro avg       0.66      0.66      0.66      9721
# weighted avg       0.71      0.71      0.71      9721

# %% [markdown]
# # Trích xuất các đặc trưng quan trọng cho từng lớp

# %%
feature_names = np.array(tfidf.get_feature_names_out())
log_probs = mnb.feature_log_prob_

# %%
for i, class_label in enumerate(le.classes_):
    top_indices = np.argsort(log_probs[i])[::-1][:20]
    print(f"\n🔹 Top 20 từ quan trọng nhất cho lớp '{class_label}':")
    for idx in top_indices:
        print(f"{feature_names[idx]}: {log_probs[i][idx]:.4f}")
# Out:
# 🔹 Top 20 từ quan trọng nhất cho lớp 'Negative':
# not: -2.9887
# feet: -4.5472
# shoe: -4.6484
# really: -4.6635
# size: -4.6640
# too: -4.6844
# very: -4.7097
# so: -4.8240
# wear: -5.1745
# not not: -5.1957
# pair: -5.3061
# small: -5.3463
# foot: -5.4540
# all: -5.5010
# back: -5.5272
# return: -5.5374
# cannot: -5.5448
# than: -5.5867
# because: -5.5972
# when: -5.6275
#
# 🔹 Top 20 từ quan trọng nhất cho lớp 'Neutral':
# not: -3.0474
# feet: -4.4131
# size: -4.4895
# shoe: -4.6506
# really: -4.6681
# too: -4.7504
# so: -4.7974
# very: -4.8232
# wear: -4.9627
# not not: -5.2668
# comfortable: -5.2684
# small: -5.2983
# than: -5.2991
# good: -5.3203
# little: -5.3446
# foot: -5.4448
# pair: -5.4903
# because: -5.5231
# cut: -5.5457
# look: -5.5767
#
# 🔹 Top 20 từ quan trọng nhất cho lớp 'Positive':
# not: -3.3171
# feet: -4.3060
# very: -4.4991
# great: -4.5433
# comfortable: -4.5826
# so: -4.6123
# love: -4.6333
# really: -4.7005
# size: -4.7041
# wear: -4.8119
# shoe: -4.8369
# good: -4.9735
# pair: -5.1785
# all: -5.2425
# little: -5.2443
# cannot: -5.3840
# well: -5.4264
# than: -5.4384
# too: -5.4485
# nice: -5.4713

# %% [markdown]
# # In ra 20 trường hợp dự đoán sai

# %%
y_test_labels = le.inverse_transform(np.array(y_test))
y_pred_labels = le.inverse_transform(np.array(y_pred))

# %%
cleaned_texts = test_df['cleaned_text'].tolist()
no_stopwords_texts = test_df['no_stopwords'].tolist()

# %%
wrong_indices = np.where(y_test != y_pred)[0]

# %%
for i in wrong_indices[:20]:
    print(f"Mẫu trước khi loại bỏ Stopwords: {cleaned_texts[i]}")
    print(f"Mẫu sau khi loại bỏ Stopwords: {no_stopwords_texts[i]}")
    print(f"Nhãn thực sự: {y_test_labels[i]}")
    print(f"Nhãn dự đoán: {y_pred_labels[i]}")
# Out:
# Mẫu trước khi loại bỏ Stopwords: they are are not comfortable what so ever and i got blisters so i no longer wear them
# Mẫu sau khi loại bỏ Stopwords: not comfortable so blisters so no longer wear
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Negative
# Mẫu trước khi loại bỏ Stopwords: delivery and everything was fine however but i cannot put anything with much weight in it is without the candles coming out of place
# Mẫu sau khi loại bỏ Stopwords: delivery everything fine however cannot put anything much weight without candles coming place
# Nhãn thực sự: Negative
# Nhãn dự đoán: Positive
# Mẫu trước khi loại bỏ Stopwords: i love the shoe very comfortable feet it is perfect then the second time i wore them i leaned back and the heel popped i hope i cannot fix them this was the shoe that is i was going to try in all the colors but probably not now
# Mẫu sau khi loại bỏ Stopwords: love shoe very comfortable feet perfect then second time wore leaned back heel popped hope cannot fix shoe going try all colors probably not now
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Positive
# Mẫu trước khi loại bỏ Stopwords: the shoe soles are quite thin it is seems like for indoor use only not for walking or running outside definitely not for cross training
# Mẫu sau khi loại bỏ Stopwords: shoe soles quite thin seems indoor only not walking running outside definitely not cross training
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Positive
# Mẫu trước khi loại bỏ Stopwords: first of all i order the shoe in black all identification laboring on box indicated that is the box contained the correct shoe unfortunately upon opening the box i found a navy blue white mixed shoe once over my anger i tried the she is on they are we are very comfortable i wear them all day and my feet does not not burn or hurt i have not ordered another pair hopefully they are will be black as i requested
# Mẫu sau khi loại bỏ Stopwords: first all order shoe black all identification laboring box indicated box contained correct shoe unfortunately upon opening box found navy blue white mixed shoe once anger tried very comfortable wear all day feet not not burn hurt not ordered another pair hopefully black requested
# Nhãn thực sự: Negative
# Nhãn dự đoán: Positive
# Mẫu trước khi loại bỏ Stopwords: huge they are we are much larger than what they are look like online or my head it is just small either way you returned them
# Mẫu sau khi loại bỏ Stopwords: huge much larger than look online head small way returned
# Nhãn thực sự: Negative
# Nhãn dự đoán: Neutral
# Mẫu trước khi loại bỏ Stopwords: nice but too big the size my size 5 5 but like size 7
# Mẫu sau khi loại bỏ Stopwords: nice too big size size 5 5 size 7
# Nhãn thực sự: Negative
# Nhãn dự đoán: Neutral
# Mẫu trước khi loại bỏ Stopwords: these are way too stiff for me i like more flexibility in my running she is i have decided to just wear my regular vivobarefoot running she is on the trails
# Mẫu sau khi loại bỏ Stopwords: way too stiff more flexibility running decided wear regular vivobarefoot running trails
# Nhãn thực sự: Negative
# Nhãn dự đoán: Neutral
# Mẫu trước khi loại bỏ Stopwords: very good
# Mẫu sau khi loại bỏ Stopwords: very good
# Nhãn thực sự: Negative
# Nhãn dự đoán: Positive
# Mẫu trước khi loại bỏ Stopwords: i had 3 friends listen while i wore them and traveled at different speed and they are said the same thing
# Mẫu sau khi loại bỏ Stopwords: 3 friends listen wore traveled different speed said same thing
# Nhãn thực sự: Positive
# Nhãn dự đoán: Negative
# Mẫu trước khi loại bỏ Stopwords: they are worked well enough for a wedding i love the look but had to take them off under the table at dinner because they are we are hurting my feet
# Mẫu sau khi loại bỏ Stopwords: worked well enough wedding love look take off table dinner because hurting feet
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Positive
# Mẫu trước khi loại bỏ Stopwords: this was my second pair of sank s i was disappointed in this pair i cannot only wear about an 1 hour due to hurting the back of my heal
# Mẫu sau khi loại bỏ Stopwords: second pair sank s disappointed pair cannot only wear 1 hour due hurting back heal
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Negative
# Mẫu trước khi loại bỏ Stopwords: i ordered my size 8 5 b but these she is we are to wide on my foot i liked the looks of them but they are we are just to big and i sent them back
# Mẫu sau khi loại bỏ Stopwords: ordered size 8 5 b wide foot liked looks big sent back
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Negative
# Mẫu trước khi loại bỏ Stopwords: great for keys lipstick and some money or money card forget about adding the phone too narrow one of the candles broke after a few uses i will keep it is and go to a shoemakers to see if he is cannot fix it is
# Mẫu sau khi loại bỏ Stopwords: great keys lipstick money money card forget adding phone too narrow candles broke uses keep go shoemakers see cannot fix
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Negative
# Mẫu trước khi loại bỏ Stopwords: looked fine too small returned
# Mẫu sau khi loại bỏ Stopwords: looked fine too small returned
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Negative
# Mẫu trước khi loại bỏ Stopwords: they are okay they are look a little cheap definitely will just be used for running around
# Mẫu sau khi loại bỏ Stopwords: okay look little cheap definitely running around
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Positive
# Mẫu trước khi loại bỏ Stopwords: unfortunately although i i am a size 7 the shoe was somewhat large even with socks it is would not have not been too large so i decided to return them
# Mẫu sau khi loại bỏ Stopwords: unfortunately although size 7 shoe somewhat large even socks not not too large so decided return
# Nhãn thực sự: Negative
# Nhãn dự đoán: Neutral
# Mẫu trước khi loại bỏ Stopwords: too small lenses too close together and not wide enough
# Mẫu sau khi loại bỏ Stopwords: too small lenses too close together not wide enough
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Negative
# Mẫu trước khi loại bỏ Stopwords: although i do not need not a special shoe size my feet are widest and i have not found that is among the popular lip flop bands reeds run a tiny bit wider than average i own i have or so pairs and i have been very happy with all of them unfortunately this model runs unusually narrow i held them up to another pair of reeds same size and they are we are at least a centimetres narrowed my feet weren t actually hanging off but it is looked silly to have not plenty of room around the toes and heel but absolutely none on the sides
# Mẫu sau khi loại bỏ Stopwords: although not need not special shoe size feet widest not found among popular lip flop bands reeds run tiny bit wider than average own so pairs very happy all unfortunately model runs unusually narrow held another pair reeds same size least centimetres narrowed feet weren t actually hanging off looked silly not plenty room around toes heel absolutely none sides
# Nhãn thực sự: Negative
# Nhãn dự đoán: Neutral
# Mẫu trước khi loại bỏ Stopwords: i was really looking forward to receiving these eyeglasses but when i did the frame was crooked i had read a few reviews with the same problem but i really did not think they are would not be as bad as they are are i am just hoping my optical cannot correct this
# Mẫu sau khi loại bỏ Stopwords: really looking forward receiving eyeglasses when frame crooked read reviews same problem really not think not bad hoping optical cannot correct
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Negative
