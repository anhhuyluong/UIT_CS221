# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, StratifiedKFold
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.stats import uniform, loguniform

# %%
from google.colab import drive
drive.mount('/content/Drive')
# Out:
# Mounted at /content/Drive

# %%
train_df = pd.read_csv('/content/Drive/My Drive/CS221_Datasets/after_clean_train.csv')
test_df = pd.read_csv('/content/Drive/My Drive/CS221_Datasets/after_clean_test.csv')

# %%
train_df.dropna(subset=['no_stopwords'], inplace=True)
test_df.dropna(subset=['no_stopwords'], inplace=True)

# %%
le = LabelEncoder()
train_df['labels'] = le.fit_transform(train_df['labels'])
test_df['labels'] = le.transform(test_df['labels'])

# %%
le.classes_
# Out:
# array(['Negative', 'Neutral', 'Positive'], dtype=object)

# %% [markdown]
# # Chia dữ liệu huấn luyện thành hai tập train và validation để tìm tham số tối ưu

# %%
X_train, X_val, y_train, y_val = train_test_split(train_df['no_stopwords'], train_df['labels'], test_size=0.2, stratify=train_df['labels'], random_state=42)

# %%
pipe_svm = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('clf', LinearSVC())
])

# %% [markdown]
# # Sử dụng RandomizedSearchCV để thu hẹp phạm vi tìm kiếm

# %%
param_dist_svm = {
    # TF-IDF
    'tfidf__max_features': [3000, 5000, 10000, 15000],
    'tfidf__ngram_range': [(1,1), (1,2), (1,3)],
    'tfidf__min_df': [1, 2, 3],
    'tfidf__sublinear_tf': [True, False],
    'tfidf__use_idf': [True, False],
    'tfidf__norm': ['l1', 'l2', None],

    # SVM
    'clf__C': uniform(0.01, 10),  # từ 0.01 đến 10
    'clf__loss': ['hinge', 'squared_hinge']
}

# %%
random_search_svm = RandomizedSearchCV(
    pipe_svm,
    param_distributions=param_dist_svm,
    n_iter=30,
    scoring='f1_weighted',
    cv=3,
    verbose=2,
    n_jobs=-1,
    random_state=42
)

random_search_svm.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# RandomizedSearchCV(cv=3,
#                    estimator=Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                                              ('clf', LinearSVC())]),
#                    n_iter=30, n_jobs=-1,
#                    param_distributions={'clf__C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x79b0dc175650>,
#                                         'clf__loss': ['hinge', 'squared_hinge'],
#                                         'tfidf__max_features': [3000, 5000,
#                                                                 10000, 15000],
#                                         'tfidf__min_df': [1, 2, 3],
#                                         'tfidf__ngram_range': [(1, 1), (1, 2),
#                                                                (1, 3)],
#                                         'tfidf__norm': ['l1', 'l2', None],
#                                         'tfidf__sublinear_tf': [True, False],
#                                         'tfidf__use_idf': [True, False]},
#                    random_state=42, scoring='f1_weighted', verbose=2)

# %%
print("Best params:", random_search_svm.best_params_)
print("Best score:", random_search_svm.best_score_)
# Out:
# Best params: {'clf__C': np.float64(0.4766566321361543), 'clf__loss': 'squared_hinge', 'tfidf__max_features': 15000, 'tfidf__min_df': 3, 'tfidf__ngram_range': (1, 2), 'tfidf__norm': 'l2', 'tfidf__sublinear_tf': True, 'tfidf__use_idf': False}
# Best score: 0.700611220574275

# %% [markdown]
# # Sử dụng GridSearchCV để tìm tham số tối ưu cuối cùng

# %%
param_grid_svm = {
    'tfidf__max_features': [15000],
    'tfidf__min_df': [3],
    'tfidf__ngram_range': [(1, 2)],
    'tfidf__sublinear_tf': [True],
    'tfidf__use_idf': [False, True],   
    'tfidf__norm': ['l2'],

    'clf__C': [0.3, 0.5, 0.7],
    'clf__loss': ['squared_hinge']
}

# %%
grid_search_svm = GridSearchCV(
    estimator=pipe_svm,
    param_grid=param_grid_svm,
    scoring='f1_weighted',
    cv=3,
    verbose=2,
    n_jobs=-1
)
grid_search_svm.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                                        ('clf', LinearSVC())]),
#              n_jobs=-1,
#              param_grid={'clf__C': [0.3, 0.5, 0.7],
#                          'clf__loss': ['squared_hinge'],
#                          'tfidf__max_features': [15000], 'tfidf__min_df': [3],
#                          'tfidf__ngram_range': [(1, 2)], 'tfidf__norm': ['l2'],
#                          'tfidf__sublinear_tf': [True],
#                          'tfidf__use_idf': [False, True]},
#              scoring='f1_weighted', verbose=2)

# %%
grid_search_svm.best_params_
# Out:
# {'clf__C': 0.5,
#  'clf__loss': 'squared_hinge',
#  'tfidf__max_features': 15000,
#  'tfidf__min_df': 3,
#  'tfidf__ngram_range': (1, 2),
#  'tfidf__norm': 'l2',
#  'tfidf__sublinear_tf': True,
#  'tfidf__use_idf': False}

# %% [markdown]
# # Dự đoán trên tập Validation

# %%
y_pred_val = grid_search_svm.predict(X_val)
print(classification_report(y_val, y_pred_val))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.86      0.79      6964
#            1       0.47      0.23      0.31      3488
#            2       0.78      0.86      0.82      6540
#
#     accuracy                           0.73     16992
#    macro avg       0.66      0.65      0.64     16992
# weighted avg       0.70      0.73      0.70     16992

# %% [markdown]
# # Train trên toàn bộ dữ liệu huấn luyện với tham số được lấy từ GridSearch ở trên

# %%
train_df = pd.read_csv('/content/Drive/My Drive/CS221_Datasets/after_clean_train.csv')
test_df = pd.read_csv('/content/Drive/My Drive/CS221_Datasets/after_clean_test.csv')

# %%
train_df.dropna(subset=['no_stopwords'], inplace=True)
test_df.dropna(subset=['no_stopwords'], inplace=True)

# %%
le = LabelEncoder()
train_df['labels'] = le.fit_transform(train_df['labels'])
test_df['labels'] = le.transform(test_df['labels'])

# %%
X_train, X_test, y_train, y_test = train_df['no_stopwords'], test_df['no_stopwords'], train_df['labels'], test_df['labels']

# %%
tfidf = TfidfVectorizer(max_features=15000, min_df=3, ngram_range=(1, 2), norm='l2', sublinear_tf=True, use_idf=False)
svc = LinearSVC(C=0.5, loss='squared_hinge')

# %%
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %%
svc.fit(X_train_tfidf, y_train)
# Out:
# LinearSVC(C=0.5)

# %% [markdown]
# # Dự đoán trên dữ liệu kiểm thử

# %%
y_pred = svc.predict(X_test_tfidf)

# %%
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.7351095566299763
#               precision    recall  f1-score   support
#
#            0       0.74      0.87      0.80      3960
#            1       0.46      0.22      0.30      1930
#            2       0.79      0.85      0.82      3831
#
#     accuracy                           0.74      9721
#    macro avg       0.66      0.65      0.64      9721
# weighted avg       0.71      0.74      0.71      9721

# %% [markdown]
# # In ra các hệ số biểu diễn mức độ quan trọng của từng đặc trưng

# %%
feature_names = np.array(tfidf.get_feature_names_out())
coef = svc.coef_

# %%
for i, class_label in enumerate(le.classes_):
    top_indices = np.argsort(coef[i])[-20:][::-1]
    print(f"\n🔹 Top 20 từ quan trọng nhất cho lớp {class_label}:")
    for idx in top_indices:
        print(f"{feature_names[idx]}: {coef[i][idx]:.4f}")
# Out:
# 🔹 Top 20 từ quan trọng nhất cho lớp Negative:
# not happy: 2.5754
# worst: 2.5582
# no good: 2.5407
# horrible: 2.4250
# most uncomfortable: 2.4240
# terrible: 2.4209
# useless: 2.3836
# wanted love: 2.3727
# not money: 2.3262
# not worth: 2.2765
# going back: 2.2274
# poor: 2.1171
# suck: 2.0758
# dangerous: 1.9878
# not good: 1.9488
# poorly: 1.9405
# not work: 1.8566
# very disappointed: 1.8183
# june: 1.8129
# tore: 1.7718
#
# 🔹 Top 20 từ quan trọng nhất cho lớp Neutral:
# little disappointed: 2.1273
# not most: 1.9852
# okay not: 1.7281
# top very: 1.6129
# sure great: 1.5767
# not bad: 1.5716
# max: 1.5479
# beautiful not: 1.5442
# not cushion: 1.5123
# wear quickly: 1.4947
# kept anyway: 1.4782
# cannot really: 1.4570
# than typical: 1.4451
# less comfortable: 1.4365
# boot too: 1.4308
# broke month: 1.4257
# beautiful too: 1.4002
# quiet: 1.3787
# than most: 1.3633
# kind narrow: 1.3628
#
# 🔹 Top 20 từ quan trọng nhất cho lớp Positive:
# not hurt: 2.8708
# not disappointed: 2.5812
# never disappointed: 2.4299
# go wrong: 2.3433
# only issue: 2.1746
# wonderful: 2.0991
# favorite: 2.0472
# glad: 2.0388
# not uncomfortable: 2.0066
# love: 2.0034
# compliments: 2.0031
# perfect: 1.9601
# only reason: 1.9060
# four stars: 1.8998
# perfectly: 1.8797
# even better: 1.8511
# great: 1.8405
# best: 1.8400
# so far: 1.8246
# tiny bit: 1.8206

# %% [markdown]
# # In ra 20 trường hợp dự đoán sai

# %%
y_test_labels = le.inverse_transform(np.array(y_test))
y_pred_labels = le.inverse_transform(np.array(y_pred))

cleaned_texts = test_df['cleaned_text'].tolist()
no_stopwords_texts = test_df['no_stopwords'].tolist()

wrong_indices = np.where(y_test != y_pred)[0]

for i in wrong_indices[:20]:
    print(f"Mẫu trước khi loại bỏ Stopwords: {cleaned_texts[i]}")
    print(f"Mẫu sau khi loại bỏ Stopwords: {no_stopwords_texts[i]}")
    print(f"Nhãn thực sự: {y_test_labels[i]}")
    print(f"Nhãn dự đoán: {y_pred_labels[i]}")
# Out:
# Mẫu trước khi loại bỏ Stopwords: they are are not comfortable what so ever and i got blisters so i no longer wear them
# Mẫu sau khi loại bỏ Stopwords: not comfortable so blisters so no longer wear
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Negative
# Mẫu trước khi loại bỏ Stopwords: bag came seeking of milder or mold
# Mẫu sau khi loại bỏ Stopwords: bag came seeking milder mold
# Nhãn thực sự: Negative
# Nhãn dự đoán: Positive
# Mẫu trước khi loại bỏ Stopwords: she is look amazing but run smaller than i was expecting also the sole of one of the she is was coming off i had to superglue it is not a problem but should not have not had to do that is with new she is
# Mẫu sau khi loại bỏ Stopwords: look amazing run smaller than expecting sole coming off superglue not problem not not new
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Negative
# Mẫu trước khi loại bỏ Stopwords: very comfortable size was right looks good but the first season the material around the edge started to show ware strap came away from the sole needed blue in multiple places to keep sole attached a one season scandal
# Mẫu sau khi loại bỏ Stopwords: very comfortable size right looks good first season material around edge started show ware strap came away sole needed blue multiple places keep sole attached season scandal
# Nhãn thực sự: Negative
# Nhãn dự đoán: Neutral
# Mẫu trước khi loại bỏ Stopwords: i love the shoe very comfortable feet it is perfect then the second time i wore them i leaned back and the heel popped i hope i cannot fix them this was the shoe that is i was going to try in all the colors but probably not now
# Mẫu sau khi loại bỏ Stopwords: love shoe very comfortable feet perfect then second time wore leaned back heel popped hope cannot fix shoe going try all colors probably not now
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Positive
# Mẫu trước khi loại bỏ Stopwords: the shoe soles are quite thin it is seems like for indoor use only not for walking or running outside definitely not for cross training
# Mẫu sau khi loại bỏ Stopwords: shoe soles quite thin seems indoor only not walking running outside definitely not cross training
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Negative
# Mẫu trước khi loại bỏ Stopwords: nice but too big the size my size 5 5 but like size 7
# Mẫu sau khi loại bỏ Stopwords: nice too big size size 5 5 size 7
# Nhãn thực sự: Negative
# Nhãn dự đoán: Neutral
# Mẫu trước khi loại bỏ Stopwords: i like how they are look but they are are too small for my face
# Mẫu sau khi loại bỏ Stopwords: how look too small face
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Negative
# Mẫu trước khi loại bỏ Stopwords: very good
# Mẫu sau khi loại bỏ Stopwords: very good
# Nhãn thực sự: Negative
# Nhãn dự đoán: Positive
# Mẫu trước khi loại bỏ Stopwords: i usually wear size 6 5 to 7 i ordered 7 but found them to be too small and narrow even though i have not narrow feet the odd thing was it is felt even way tighter on my right foot than the left which had never happened before too late to return or exchange for a larger size definitely need not to go up a half size or even a full size bigger than usual
# Mẫu sau khi loại bỏ Stopwords: usually wear size 6 5 7 ordered 7 found too small narrow even though not narrow feet odd thing felt even way tighter right foot than left never happened too late return exchange larger size definitely need not go half size even full size bigger than usual
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Negative
# Mẫu trước khi loại bỏ Stopwords: i had 3 friends listen while i wore them and traveled at different speed and they are said the same thing
# Mẫu sau khi loại bỏ Stopwords: 3 friends listen wore traveled different speed said same thing
# Nhãn thực sự: Positive
# Nhãn dự đoán: Negative
# Mẫu trước khi loại bỏ Stopwords: if you are looking to buy these then you are making a good choice unless you have not larger feet if you have not big feet then you cannot understand that is when you put on a shoe it is just does not not look right compared to other people sometimes these she is seem to be a fair quality for the price the she is i received did not have not anything out of the ordinary on them when i tried them on they are feet big size us but so the leather if it is it is real did not matter to me shaped weird around my foot but that is it is
# Mẫu sau khi loại bỏ Stopwords: looking buy then making good choice unless not larger feet not big feet then cannot understand when put shoe not not look right compared other people sometimes seem fair quality price received not not anything ordinary when tried feet big size us so leather real not matter shaped weird around foot
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Negative
# Mẫu trước khi loại bỏ Stopwords: they are worked well enough for a wedding i love the look but had to take them off under the table at dinner because they are we are hurting my feet
# Mẫu sau khi loại bỏ Stopwords: worked well enough wedding love look take off table dinner because hurting feet
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Positive
# Mẫu trước khi loại bỏ Stopwords: this was my second pair of sank s i was disappointed in this pair i cannot only wear about an 1 hour due to hurting the back of my heal
# Mẫu sau khi loại bỏ Stopwords: second pair sank s disappointed pair cannot only wear 1 hour due hurting back heal
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Negative
# Mẫu trước khi loại bỏ Stopwords: i ordered my size 8 5 b but these she is we are to wide on my foot i liked the looks of them but they are we are just to big and i sent them back
# Mẫu sau khi loại bỏ Stopwords: ordered size 8 5 b wide foot liked looks big sent back
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Negative
# Mẫu trước khi loại bỏ Stopwords: great for keys lipstick and some money or money card forget about adding the phone too narrow one of the candles broke after a few uses i will keep it is and go to a shoemakers to see if he is cannot fix it is
# Mẫu sau khi loại bỏ Stopwords: great keys lipstick money money card forget adding phone too narrow candles broke uses keep go shoemakers see cannot fix
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Negative
# Mẫu trước khi loại bỏ Stopwords: i like the shoe just fine but the faces are annoying they are thin and i do not know what to do with the big loop that is left
# Mẫu sau khi loại bỏ Stopwords: shoe fine faces annoying thin not know big loop left
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Negative
# Mẫu trước khi loại bỏ Stopwords: unfortunately although i i am a size 7 the shoe was somewhat large even with socks it is would not have not been too large so i decided to return them
# Mẫu sau khi loại bỏ Stopwords: unfortunately although size 7 shoe somewhat large even socks not not too large so decided return
# Nhãn thực sự: Negative
# Nhãn dự đoán: Neutral
# Mẫu trước khi loại bỏ Stopwords: they are run about half size small
# Mẫu sau khi loại bỏ Stopwords: run half size small
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Negative
# Mẫu trước khi loại bỏ Stopwords: too small lenses too close together and not wide enough
# Mẫu sau khi loại bỏ Stopwords: too small lenses too close together not wide enough
# Nhãn thực sự: Neutral
# Nhãn dự đoán: Negative
